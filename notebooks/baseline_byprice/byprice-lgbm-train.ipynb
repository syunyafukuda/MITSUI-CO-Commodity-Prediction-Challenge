# %% [markdown]
# # Price → Log-Return (Two-Stage Inference) Baseline Design Notes
#
# ## Objective
#
# Instead of directly regressing on the log-return,
#
# - Stage A: Predict the price
# - Stage B: Synthesize the log-return from the predicted price and historical prices
#
# This two-stage inference aims to improve accuracy and stability.
#
# ---
#
# ## Background and Objectives
#
# - Return is scale-invariant and easy to handle, but it is difficult to utilize price dynamics (autocorrelation and seasonality).
# - In practice, it is common to estimate prices and take the difference.
# - Utilizing price model information (predicted values and error structure) to stabilize return synthesis.
#
# ---
#
# ## Overall Flow
#
# ### Stage-A (Training) — Price Model
#
# - Extract price columns (A and B) appearing in `target_pairs.csv`
# - Regression using LightGBM (GPU) for each price column
# - Objective variable: `y = log(price)` (restored using `exp` during inference)
# - Prevent leaks: Exclude the target price column from the features.
#
# ### Stage-B (Submission) — Price → Return Synthesis
#
# - Read price models (`.txt`) and `meta`
# - Rolling Price Store (history based on `date_id`)
# - Current price `P_t(*)`:
# - Prioritize actual measurements if available; otherwise, use model predictions.
# - Lagged price `P_{t-L}(*)`: Obtain from store.
# - Calculate log-return based on `pair`:
# - Single: `log(P_t(A)) - log(P_{t-L}(A))`
# - `"A - B"`: `log(P_t(A)) - log(P_{t-L}(B))`
# - Failsafe = 0.0 for insufficient history or non-positive values.
#
# ---
#
# ## Validation Design (Offline)
#
# - Sort `train.csv` in ascending order by `date_id` and apply `TimeSeriesSplit(k=5)`.
# - Evaluate the pricing model using **price RMSE**.
# - Additional validation (optional):
# - Use the last 10% of the training data as the validation interval.
# - Output `P̂_t(A)` using the price model.
# - Reference `P_{t-L}(B)` from the real data (no leaks allowed).
# - Synthesize `ŷ_return = log(P̂_t(A)) - log(P_{t-L}(B))`.
# - Compare RMSE/MAE with the existing "return direct regression baseline."
#
# ---
#
# ## Steps (Execution Order)
#
# - Execute the learning notebook (Stage-A)
# - Output the results to /kaggle/working/models_price/.
# - Publish using "Create Dataset" (e.g., mitsui-price-models).
#
# - Add to Add Data in the submission notebook (Stage-B)
# - Set MODEL_INPUT_DIR to the models_price of the published dataset.
#
# ---
#
# ## Reproducibility
#
# - Fixed random_state=42.
#
# - Save only the best fold of price CV to a txt file → The submitter loads Booster for full reproduction.
#
# - Preprocessing (object → numeric / category → codes), feat_cols_base recorded in meta.
#
# ---
#
# ## Related URLs
# - Datasets -> https://www.kaggle.com/datasets/shunyafukuda/mitsui-byprice-lgbm-v1
# - submit notebook -> https://www.kaggle.com/code/shunyafukuda/byprice-lgbm-submit

# %%
# =============================== #
# Price-First TRAIN (GPU-only)    #
# - resumable, progress, quiet    #
# - single-GPU sequential         #
# =============================== #

import os, json, time, warnings, re, logging
warnings.filterwarnings("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"
logging.getLogger("lightgbm").setLevel(logging.ERROR)

import numpy as np
import pandas as pd
from tqdm.auto import tqdm

# ---- LightGBM のインストールは別セルで先に実行するとさらに静かになります ----
# try:
#     import lightgbm as lgb
# except ImportError:
#     !pip -qq install --upgrade lightgbm
#     import lightgbm as lgb
import lightgbm as lgb

from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

# ---------------- Paths/Config ----------------
DATA_PATH  = "/kaggle/input/mitsui-commodity-prediction-challenge"
TRAIN_CSV  = f"{DATA_PATH}/train.csv"
TEST_CSV   = f"{DATA_PATH}/test.csv"
PAIRS_CSV  = f"{DATA_PATH}/target_pairs.csv"

OUT_DIR    = "/kaggle/working/models_price"
os.makedirs(OUT_DIR, exist_ok=True)

LOG_JSONL  = os.path.join(OUT_DIR, "train_price_progress.jsonl")  # 逐次ログ
METRICS_CSV= os.path.join(OUT_DIR, "cv_price_metrics.csv")        # 成功分の集計

# ---- 学習ハイパラ（GPU前提）----
N_SPLITS       = 5        # 重ければ 3 に
USE_LOG_PRICE  = True     # y=log(price)
MIN_SAMPLES    = 200      # 小さすぎる列はスキップ
LGB_PARAMS = dict(
    n_estimators=2000, learning_rate=0.03, num_leaves=31,
    feature_fraction=0.8, bagging_fraction=0.8, bagging_freq=1,
    max_bin=255, random_state=42, verbosity=-1,
    device_type="gpu", gpu_platform_id=0, gpu_device_id=0,
)
CALLBACKS = [lgb.log_evaluation(period=0), lgb.early_stopping(stopping_rounds=100)]

# ---------------- Utils ----------------
def preprocess_for_lgbm(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    obj = df.select_dtypes(include=["object"]).columns
    if len(obj) > 0:
        df[obj] = df[obj].apply(pd.to_numeric, errors="coerce")
    for c in df.select_dtypes(include=["category"]).columns:
        df[c] = df[c].cat.codes
    return df

def parse_pair_string(s: str) -> tuple[str | None, str | None]:
    """'A - B' -> ('A','B'), 'A' -> ('A', None)"""
    if " - " in s:
        a, b = s.split(" - ", 1)
        return a.strip(), b.strip()
    return s.strip(), None

def append_jsonl(path: str, obj: dict):
    with open(path, "a", encoding="utf-8") as f:
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

def already_done_cols(out_dir: str) -> set[str]:
    done = set()
    for fname in os.listdir(out_dir):
        if fname.startswith("price__") and fname.endswith(".txt"):
            done.add(fname[len("price__"):-4])
    return done

# ---------------- Load ----------------
train_raw = pd.read_csv(TRAIN_CSV)
test_raw  = pd.read_csv(TEST_CSV)
pairs     = pd.read_csv(PAIRS_CSV)

assert "date_id" in train_raw.columns, "train.csv に date_id がありません"
assert set(["target","lag","pair"]).issubset(pairs.columns), "target_pairs.csv は target,lag,pair の3列が必要です"

train = preprocess_for_lgbm(train_raw)
test  = preprocess_for_lgbm(test_raw)

num_train_cols = train.select_dtypes(include=[np.number]).columns.tolist()
num_test_cols  = test.select_dtypes(include=[np.number]).columns.tolist()
feat_cols_base = sorted(set(num_train_cols).intersection(num_test_cols))
feat_cols_base = [c for c in feat_cols_base if c != "date_id"]

# ---- 学習対象の価格列（pairに登場する列名）を厳密抽出 ----
required_price_cols = set()
for _, row in pairs.iterrows():
    a, b = parse_pair_string(str(row["pair"]))
    if a is not None: required_price_cols.add(a)
    if b is not None: required_price_cols.add(b)

missing = [col for col in required_price_cols if col not in train.columns]
assert len(missing) == 0, f"pair で参照される列が train.csv にありません: {missing}"

# ---- 時系列順 ----
df = train.sort_values("date_id").reset_index(drop=True)

# ---------------- Core: per-price-column training ----------------
def train_one_pricecol(pcol: str) -> dict:
    """1つの価格列に対して LGBM(GPU) を学習し、モデル保存＆メトリクス返却"""
    t_start = time.time()
    out = {"price_col": pcol, "status": "skipped", "rmse": None, "secs": 0.0, "n": 0}

    model_path = os.path.join(OUT_DIR, f"price__{pcol}.txt")
    if os.path.exists(model_path):
        out["status"] = "exists"
        return out

    y = df[pcol].astype(float).values
    mask = np.isfinite(y)
    Xc, yc = df.loc[mask, feat_cols_base + ["date_id"]], y[mask]
    out["n"] = len(yc)
    if len(yc) < MIN_SAMPLES:
        out["status"] = "too_few_samples"
        append_jsonl(LOG_JSONL, {**out, "ts": time.time()})
        return out

    # リーク防止：同じ列を特徴から除外
    feat_cols = [c for c in feat_cols_base if c != pcol]
    yc_tr = np.log(np.clip(yc, 1e-12, None)) if USE_LOG_PRICE else yc

    tss = TimeSeriesSplit(n_splits=N_SPLITS)
    best_model, best_rmse = None, np.inf

    for fold, (tr_idx, va_idx) in enumerate(tss.split(Xc), 1):
        X_tr = Xc.iloc[tr_idx][feat_cols]
        X_va = Xc.iloc[va_idx][feat_cols]
        y_tr = yc_tr[tr_idx]
        y_va = yc_tr[va_idx]

        model = lgb.LGBMRegressor(**LGB_PARAMS)
        model.fit(X_tr, y_tr, eval_set=[(X_va, y_va)],
                  eval_metric="rmse", callbacks=CALLBACKS)

        pred = model.predict(X_va, num_iteration=getattr(model, "best_iteration_", None))
        if USE_LOG_PRICE:
            pred = np.exp(pred)
            y_va_eval = np.exp(y_va)
        else:
            y_va_eval = y_va

        rmse = mean_squared_error(y_va_eval, pred, squared=False)
        if rmse < best_rmse:
            best_rmse, best_model = rmse, model

    if best_model is not None:
        best_model.booster_.save_model(model_path)
        out["status"] = "ok"
        out["rmse"]   = float(best_rmse)

    out["secs"] = time.time() - t_start
    append_jsonl(LOG_JSONL, {**out, "ts": time.time()})
    return out

# ---------------- Run (single-GPU sequential) ----------------
price_cols_sorted = sorted(required_price_cols)
done_before = already_done_cols(OUT_DIR)
todo_cols   = [c for c in price_cols_sorted if c not in done_before]

print(f"Total targets = {len(price_cols_sorted)} | resume skipped = {len(done_before)} | to-train = {len(todo_cols)}")

results = []
t0 = time.time()
for col in tqdm(todo_cols, ascii=True, desc="train(price cols) [GPU]"):
    results.append(train_one_pricecol(col))
elapsed = time.time() - t0
print(f"Done. elapsed={elapsed/60:.1f} min")

# ---------------- Save metrics (append-safe) ----------------
prev = None
if os.path.exists(METRICS_CSV):
    try:
        prev = pd.read_csv(METRICS_CSV)
    except Exception:
        prev = None

df_res = pd.DataFrame(results)
df_ok  = df_res[df_res["status"]=="ok"][["price_col","rmse","secs","n"]]
merged = pd.concat([prev, df_ok], axis=0, ignore_index=True) if prev is not None else df_ok
merged.to_csv(METRICS_CSV, index=False)

# ---------------- Save meta ----------------
max_lag = int(pairs["lag"].max())
meta = {
    "feat_cols_base": feat_cols_base,
    "price_cols": price_cols_sorted,
    "use_log_price": USE_LOG_PRICE,
    "max_lag": max_lag,
    "n_splits": N_SPLITS,
    "note": "GPU-only sequential training with resume & progress.",
}
with open(os.path.join(OUT_DIR, "meta_price.json"), "w") as f:
    json.dump(meta, f)

print("Saved to:", OUT_DIR)
print("Examples:", sorted(os.listdir(OUT_DIR))[:10])
# Out:
# Total targets = 106 | resume skipped = 0 | to-train = 106
# train(price cols) [GPU]:   0%|          | 0/106 [00:00<?, ?it/s]
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1699]	valid_0's rmse: 0.0387763	valid_0's l2: 0.0015036
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1042]	valid_0's rmse: 0.0176491	valid_0's l2: 0.000311491
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1915]	valid_0's rmse: 0.0225908	valid_0's l2: 0.000510345
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [339]	valid_0's rmse: 0.0167336	valid_0's l2: 0.000280015
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [33]	valid_0's rmse: 0.0122869	valid_0's l2: 0.000150968
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1991]	valid_0's rmse: 0.0636922	valid_0's l2: 0.00405669
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [386]	valid_0's rmse: 0.0168004	valid_0's l2: 0.000282255
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [473]	valid_0's rmse: 0.0267958	valid_0's l2: 0.000718016
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1997]	valid_0's rmse: 0.074567	valid_0's l2: 0.00556024
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [602]	valid_0's rmse: 0.0327602	valid_0's l2: 0.00107323
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1995]	valid_0's rmse: 0.0641326	valid_0's l2: 0.00411299
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [200]	valid_0's rmse: 0.0167073	valid_0's l2: 0.000279134
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [152]	valid_0's rmse: 0.0607612	valid_0's l2: 0.00369192
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1967]	valid_0's rmse: 0.0272502	valid_0's l2: 0.000742574
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0335082	valid_0's l2: 0.0011228
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	valid_0's rmse: 0.0630169	valid_0's l2: 0.00397113
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [477]	valid_0's rmse: 0.0265921	valid_0's l2: 0.000707139
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [379]	valid_0's rmse: 0.0250055	valid_0's l2: 0.000625275
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0168902	valid_0's l2: 0.000285278
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1172]	valid_0's rmse: 0.0252559	valid_0's l2: 0.000637861
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [252]	valid_0's rmse: 0.0282322	valid_0's l2: 0.000797059
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [766]	valid_0's rmse: 0.014515	valid_0's l2: 0.000210687
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [212]	valid_0's rmse: 0.0196817	valid_0's l2: 0.000387371
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1053]	valid_0's rmse: 0.0642093	valid_0's l2: 0.00412284
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [525]	valid_0's rmse: 0.0335216	valid_0's l2: 0.0011237
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0256239	valid_0's l2: 0.000656582
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1232]	valid_0's rmse: 0.0241877	valid_0's l2: 0.000585044
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [648]	valid_0's rmse: 0.120831	valid_0's l2: 0.0146002
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0467459	valid_0's l2: 0.00218518
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0288818	valid_0's l2: 0.00083416
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [516]	valid_0's rmse: 0.0206366	valid_0's l2: 0.000425867
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [655]	valid_0's rmse: 0.0338827	valid_0's l2: 0.00114804
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1009]	valid_0's rmse: 0.0173754	valid_0's l2: 0.000301906
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [477]	valid_0's rmse: 0.0213014	valid_0's l2: 0.000453748
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1906]	valid_0's rmse: 0.0411369	valid_0's l2: 0.00169224
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.0188025	valid_0's l2: 0.000353532
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [238]	valid_0's rmse: 0.0320919	valid_0's l2: 0.00102989
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [906]	valid_0's rmse: 0.144829	valid_0's l2: 0.0209754
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1979]	valid_0's rmse: 0.0932766	valid_0's l2: 0.00870052
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [869]	valid_0's rmse: 0.0283515	valid_0's l2: 0.000803806
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1999]	valid_0's rmse: 0.0323883	valid_0's l2: 0.001049
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [310]	valid_0's rmse: 0.0151518	valid_0's l2: 0.000229577
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [92]	valid_0's rmse: 0.0433393	valid_0's l2: 0.0018783
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0364319	valid_0's l2: 0.00132728
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [981]	valid_0's rmse: 0.0189282	valid_0's l2: 0.000358277
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [776]	valid_0's rmse: 0.0312654	valid_0's l2: 0.000977527
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1477]	valid_0's rmse: 0.0226289	valid_0's l2: 0.000512066
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1247]	valid_0's rmse: 0.0687771	valid_0's l2: 0.00473029
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's rmse: 0.0118533	valid_0's l2: 0.000140502
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's rmse: 0.0280421	valid_0's l2: 0.000786362
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1676]	valid_0's rmse: 0.0394132	valid_0's l2: 0.0015534
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [173]	valid_0's rmse: 0.0131432	valid_0's l2: 0.000172745
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [252]	valid_0's rmse: 0.0704951	valid_0's l2: 0.00496956
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [199]	valid_0's rmse: 0.0287788	valid_0's l2: 0.000828217
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [259]	valid_0's rmse: 0.012693	valid_0's l2: 0.000161113
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [959]	valid_0's rmse: 0.019647	valid_0's l2: 0.000386006
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	valid_0's rmse: 0.0187578	valid_0's l2: 0.000351855
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1992]	valid_0's rmse: 0.0236496	valid_0's l2: 0.000559302
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [18]	valid_0's rmse: 0.0125693	valid_0's l2: 0.000157988
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1886]	valid_0's rmse: 0.0226246	valid_0's l2: 0.000511872
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1991]	valid_0's rmse: 0.0368963	valid_0's l2: 0.00136134
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [163]	valid_0's rmse: 0.0169739	valid_0's l2: 0.000288115
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1360]	valid_0's rmse: 0.0425535	valid_0's l2: 0.0018108
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [701]	valid_0's rmse: 0.0761441	valid_0's l2: 0.00579792
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [755]	valid_0's rmse: 0.0244696	valid_0's l2: 0.000598761
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [41]	valid_0's rmse: 0.0246939	valid_0's l2: 0.000609788
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [9]	valid_0's rmse: 0.023559	valid_0's l2: 0.000555027
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0412622	valid_0's l2: 0.00170257
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [121]	valid_0's rmse: 0.0138331	valid_0's l2: 0.000191354
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1999]	valid_0's rmse: 0.0166249	valid_0's l2: 0.000276389
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [322]	valid_0's rmse: 0.0301533	valid_0's l2: 0.000909222
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [946]	valid_0's rmse: 0.0376488	valid_0's l2: 0.00141744
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.0930345	valid_0's l2: 0.00865541
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [33]	valid_0's rmse: 0.0129676	valid_0's l2: 0.000168159
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [213]	valid_0's rmse: 0.0257407	valid_0's l2: 0.000662581
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0339792	valid_0's l2: 0.00115458
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [423]	valid_0's rmse: 0.0283896	valid_0's l2: 0.000805972
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1262]	valid_0's rmse: 0.0699288	valid_0's l2: 0.00489004
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1207]	valid_0's rmse: 0.070458	valid_0's l2: 0.00496434
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1978]	valid_0's rmse: 0.0386085	valid_0's l2: 0.00149062
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [657]	valid_0's rmse: 0.0191521	valid_0's l2: 0.000366803
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [374]	valid_0's rmse: 0.0091995	valid_0's l2: 8.46309e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [784]	valid_0's rmse: 0.00945867	valid_0's l2: 8.94665e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [298]	valid_0's rmse: 0.0201546	valid_0's l2: 0.000406207
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1991]	valid_0's rmse: 0.0354666	valid_0's l2: 0.00125788
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1998]	valid_0's rmse: 0.0252653	valid_0's l2: 0.000638333
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1467]	valid_0's rmse: 0.0225407	valid_0's l2: 0.000508084
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [544]	valid_0's rmse: 0.0623583	valid_0's l2: 0.00388856
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [22]	valid_0's rmse: 0.0233841	valid_0's l2: 0.000546816
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1005]	valid_0's rmse: 0.0133359	valid_0's l2: 0.000177845
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [770]	valid_0's rmse: 0.0969552	valid_0's l2: 0.00940032
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1478]	valid_0's rmse: 0.0261345	valid_0's l2: 0.000683013
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [599]	valid_0's rmse: 0.0718025	valid_0's l2: 0.0051556
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1154]	valid_0's rmse: 0.0878948	valid_0's l2: 0.00772549
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [270]	valid_0's rmse: 0.0234053	valid_0's l2: 0.000547809
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [695]	valid_0's rmse: 0.0618399	valid_0's l2: 0.00382418
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [345]	valid_0's rmse: 0.023932	valid_0's l2: 0.00057274
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's rmse: 0.0230262	valid_0's l2: 0.000530206
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1987]	valid_0's rmse: 0.0670294	valid_0's l2: 0.00449294
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [318]	valid_0's rmse: 0.0123466	valid_0's l2: 0.000152439
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1950]	valid_0's rmse: 0.064315	valid_0's l2: 0.00413642
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.013889	valid_0's l2: 0.000192904
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [411]	valid_0's rmse: 0.0187646	valid_0's l2: 0.000352108
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [944]	valid_0's rmse: 0.0806245	valid_0's l2: 0.0065003
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [833]	valid_0's rmse: 0.0306681	valid_0's l2: 0.000940534
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1995]	valid_0's rmse: 0.0956283	valid_0's l2: 0.00914477
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [127]	valid_0's rmse: 0.0170876	valid_0's l2: 0.000291985
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.089197	valid_0's l2: 0.00795611
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [49]	valid_0's rmse: 0.0366169	valid_0's l2: 0.0013408
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [331]	valid_0's rmse: 0.0304353	valid_0's l2: 0.000926308
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1498]	valid_0's rmse: 0.0828438	valid_0's l2: 0.00686309
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [29]	valid_0's rmse: 0.0300694	valid_0's l2: 0.000904169
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.101081	valid_0's l2: 0.0102173
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [684]	valid_0's rmse: 0.0361402	valid_0's l2: 0.00130611
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [847]	valid_0's rmse: 0.0205563	valid_0's l2: 0.000422562
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [452]	valid_0's rmse: 0.0469201	valid_0's l2: 0.0022015
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [401]	valid_0's rmse: 0.0136631	valid_0's l2: 0.00018668
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [527]	valid_0's rmse: 0.0557829	valid_0's l2: 0.00311173
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [365]	valid_0's rmse: 0.067237	valid_0's l2: 0.00452081
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1995]	valid_0's rmse: 0.0247679	valid_0's l2: 0.000613451
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1999]	valid_0's rmse: 0.0628582	valid_0's l2: 0.00395115
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [469]	valid_0's rmse: 0.0192397	valid_0's l2: 0.000370166
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [233]	valid_0's rmse: 0.0580475	valid_0's l2: 0.00336951
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [159]	valid_0's rmse: 0.0388633	valid_0's l2: 0.00151036
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1984]	valid_0's rmse: 0.028295	valid_0's l2: 0.000800605
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1995]	valid_0's rmse: 0.0404489	valid_0's l2: 0.00163612
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [576]	valid_0's rmse: 0.0400713	valid_0's l2: 0.00160571
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1601]	valid_0's rmse: 0.0433044	valid_0's l2: 0.00187527
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [54]	valid_0's rmse: 0.0190166	valid_0's l2: 0.000361631
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1995]	valid_0's rmse: 0.0259493	valid_0's l2: 0.000673364
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1803]	valid_0's rmse: 0.0142659	valid_0's l2: 0.000203517
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [984]	valid_0's rmse: 0.0466771	valid_0's l2: 0.00217875
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [58]	valid_0's rmse: 0.0221359	valid_0's l2: 0.000489996
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [706]	valid_0's rmse: 0.0584814	valid_0's l2: 0.00342007
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [72]	valid_0's rmse: 0.0269352	valid_0's l2: 0.000725506
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0192906	valid_0's l2: 0.000372126
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1206]	valid_0's rmse: 0.0202803	valid_0's l2: 0.000411291
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1405]	valid_0's rmse: 0.164141	valid_0's l2: 0.0269423
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [789]	valid_0's rmse: 0.0492646	valid_0's l2: 0.002427
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [962]	valid_0's rmse: 0.0597436	valid_0's l2: 0.0035693
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [795]	valid_0's rmse: 0.094108	valid_0's l2: 0.00885631
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [260]	valid_0's rmse: 0.0372265	valid_0's l2: 0.00138581
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1888]	valid_0's rmse: 0.0800578	valid_0's l2: 0.00640924
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1997]	valid_0's rmse: 0.0851131	valid_0's l2: 0.00724424
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [107]	valid_0's rmse: 0.0194825	valid_0's l2: 0.000379568
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1999]	valid_0's rmse: 0.0668836	valid_0's l2: 0.00447341
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [195]	valid_0's rmse: 0.0328241	valid_0's l2: 0.00107742
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [15]	valid_0's rmse: 0.0243134	valid_0's l2: 0.000591143
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1765]	valid_0's rmse: 0.0892273	valid_0's l2: 0.00796151
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [65]	valid_0's rmse: 0.0221093	valid_0's l2: 0.000488821
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1993]	valid_0's rmse: 0.0760851	valid_0's l2: 0.00578894
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [200]	valid_0's rmse: 0.0212941	valid_0's l2: 0.000453439
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [199]	valid_0's rmse: 0.0189263	valid_0's l2: 0.000358205
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [739]	valid_0's rmse: 0.045244	valid_0's l2: 0.00204702
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1927]	valid_0's rmse: 0.0260249	valid_0's l2: 0.000677293
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [796]	valid_0's rmse: 0.105778	valid_0's l2: 0.0111891
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [82]	valid_0's rmse: 0.0171889	valid_0's l2: 0.000295457
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0791444	valid_0's l2: 0.00626383
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [6]	valid_0's rmse: 0.0337956	valid_0's l2: 0.00114214
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [216]	valid_0's rmse: 0.0533865	valid_0's l2: 0.00285012
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [414]	valid_0's rmse: 0.0933587	valid_0's l2: 0.00871584
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [58]	valid_0's rmse: 0.0271845	valid_0's l2: 0.000738995
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.114747	valid_0's l2: 0.013167
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1209]	valid_0's rmse: 0.0673406	valid_0's l2: 0.00453476
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [212]	valid_0's rmse: 0.0151568	valid_0's l2: 0.000229728
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [354]	valid_0's rmse: 0.129904	valid_0's l2: 0.016875
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0572647	valid_0's l2: 0.00327925
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [196]	valid_0's rmse: 0.113161	valid_0's l2: 0.0128053
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [425]	valid_0's rmse: 0.119725	valid_0's l2: 0.014334
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [481]	valid_0's rmse: 0.289151	valid_0's l2: 0.0836084
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [188]	valid_0's rmse: 0.0434807	valid_0's l2: 0.00189057
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [581]	valid_0's rmse: 0.0928898	valid_0's l2: 0.00862851
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [139]	valid_0's rmse: 0.00961106	valid_0's l2: 9.23724e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [172]	valid_0's rmse: 0.0151126	valid_0's l2: 0.00022839
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1988]	valid_0's rmse: 0.0474651	valid_0's l2: 0.00225294
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [122]	valid_0's rmse: 0.11534	valid_0's l2: 0.0133033
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.182082	valid_0's l2: 0.0331538
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1207]	valid_0's rmse: 0.145395	valid_0's l2: 0.0211399
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [17]	valid_0's rmse: 0.0503402	valid_0's l2: 0.00253414
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [39]	valid_0's rmse: 0.0548674	valid_0's l2: 0.00301043
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [798]	valid_0's rmse: 0.0756803	valid_0's l2: 0.00572751
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [289]	valid_0's rmse: 0.261663	valid_0's l2: 0.0684674
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1506]	valid_0's rmse: 0.0562609	valid_0's l2: 0.00316528
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [114]	valid_0's rmse: 0.0391773	valid_0's l2: 0.00153486
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [674]	valid_0's rmse: 0.0620099	valid_0's l2: 0.00384523
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [143]	valid_0's rmse: 0.105424	valid_0's l2: 0.0111141
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.0616548	valid_0's l2: 0.00380132
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [28]	valid_0's rmse: 0.0740235	valid_0's l2: 0.00547948
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [7]	valid_0's rmse: 0.0375503	valid_0's l2: 0.00141003
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0496753	valid_0's l2: 0.00246764
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1996]	valid_0's rmse: 0.154582	valid_0's l2: 0.0238956
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [36]	valid_0's rmse: 0.0710305	valid_0's l2: 0.00504534
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [191]	valid_0's rmse: 0.269613	valid_0's l2: 0.0726914
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.122258	valid_0's l2: 0.0149471
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [496]	valid_0's rmse: 0.0507715	valid_0's l2: 0.00257775
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [91]	valid_0's rmse: 0.0549717	valid_0's l2: 0.00302189
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [416]	valid_0's rmse: 0.170238	valid_0's l2: 0.0289809
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [498]	valid_0's rmse: 0.0193685	valid_0's l2: 0.00037514
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [256]	valid_0's rmse: 0.00938401	valid_0's l2: 8.80597e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [882]	valid_0's rmse: 0.12219	valid_0's l2: 0.0149305
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [121]	valid_0's rmse: 0.148053	valid_0's l2: 0.0219196
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [272]	valid_0's rmse: 0.34477	valid_0's l2: 0.118866
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [162]	valid_0's rmse: 0.202219	valid_0's l2: 0.0408925
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [117]	valid_0's rmse: 0.0268201	valid_0's l2: 0.000719315
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [206]	valid_0's rmse: 0.0244811	valid_0's l2: 0.000599323
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [73]	valid_0's rmse: 0.0596128	valid_0's l2: 0.00355369
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [320]	valid_0's rmse: 0.279181	valid_0's l2: 0.0779418
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [246]	valid_0's rmse: 0.143385	valid_0's l2: 0.0205594
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [449]	valid_0's rmse: 0.0909881	valid_0's l2: 0.00827884
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1120]	valid_0's rmse: 0.219377	valid_0's l2: 0.0481264
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.216454	valid_0's l2: 0.0468525
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [82]	valid_0's rmse: 0.0892127	valid_0's l2: 0.0079589
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [174]	valid_0's rmse: 0.0734788	valid_0's l2: 0.00539913
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [198]	valid_0's rmse: 0.0146622	valid_0's l2: 0.000214981
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [243]	valid_0's rmse: 0.138509	valid_0's l2: 0.0191847
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0541961	valid_0's l2: 0.00293722
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1988]	valid_0's rmse: 0.0105933	valid_0's l2: 0.000112218
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [309]	valid_0's rmse: 0.0201805	valid_0's l2: 0.000407252
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [132]	valid_0's rmse: 0.00141429	valid_0's l2: 2.00022e-06
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [304]	valid_0's rmse: 0.00183807	valid_0's l2: 3.37851e-06
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1999]	valid_0's rmse: 0.0348944	valid_0's l2: 0.00121762
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1230]	valid_0's rmse: 0.284524	valid_0's l2: 0.0809539
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [108]	valid_0's rmse: 0.0479565	valid_0's l2: 0.00229982
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [424]	valid_0's rmse: 0.146296	valid_0's l2: 0.0214026
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [465]	valid_0's rmse: 0.163367	valid_0's l2: 0.0266889
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0730188	valid_0's l2: 0.00533175
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [342]	valid_0's rmse: 0.289229	valid_0's l2: 0.0836533
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1215]	valid_0's rmse: 0.180461	valid_0's l2: 0.032566
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [299]	valid_0's rmse: 0.238499	valid_0's l2: 0.0568819
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0893279	valid_0's l2: 0.00797948
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1360]	valid_0's rmse: 0.204482	valid_0's l2: 0.041813
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [291]	valid_0's rmse: 0.43687	valid_0's l2: 0.190856
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [287]	valid_0's rmse: 0.111503	valid_0's l2: 0.012433
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [109]	valid_0's rmse: 0.0214842	valid_0's l2: 0.000461571
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [127]	valid_0's rmse: 0.0483555	valid_0's l2: 0.00233825
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1996]	valid_0's rmse: 0.188423	valid_0's l2: 0.0355034
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [257]	valid_0's rmse: 0.0476751	valid_0's l2: 0.00227292
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [751]	valid_0's rmse: 0.379506	valid_0's l2: 0.144025
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [325]	valid_0's rmse: 0.0296492	valid_0's l2: 0.000879073
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [339]	valid_0's rmse: 0.027526	valid_0's l2: 0.000757681
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1997]	valid_0's rmse: 0.38876	valid_0's l2: 0.151134
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [59]	valid_0's rmse: 0.0764112	valid_0's l2: 0.00583867
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [137]	valid_0's rmse: 0.507638	valid_0's l2: 0.257697
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [141]	valid_0's rmse: 0.013616	valid_0's l2: 0.000185396
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [133]	valid_0's rmse: 0.0370357	valid_0's l2: 0.00137164
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1997]	valid_0's rmse: 0.105813	valid_0's l2: 0.0111964
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [324]	valid_0's rmse: 0.0679307	valid_0's l2: 0.00461459
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [139]	valid_0's rmse: 0.341202	valid_0's l2: 0.116419
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [96]	valid_0's rmse: 0.015917	valid_0's l2: 0.000253352
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [193]	valid_0's rmse: 0.0255091	valid_0's l2: 0.000650712
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [202]	valid_0's rmse: 0.0439385	valid_0's l2: 0.00193059
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [263]	valid_0's rmse: 0.566846	valid_0's l2: 0.321314
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [394]	valid_0's rmse: 0.0585619	valid_0's l2: 0.00342949
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	valid_0's rmse: 0.0138822	valid_0's l2: 0.000192716
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [245]	valid_0's rmse: 0.0681581	valid_0's l2: 0.00464553
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1997]	valid_0's rmse: 0.418544	valid_0's l2: 0.175179
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [80]	valid_0's rmse: 0.183162	valid_0's l2: 0.0335483
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [390]	valid_0's rmse: 0.454814	valid_0's l2: 0.206856
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [77]	valid_0's rmse: 0.0370421	valid_0's l2: 0.00137212
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [94]	valid_0's rmse: 0.0564221	valid_0's l2: 0.00318345
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [617]	valid_0's rmse: 0.0509267	valid_0's l2: 0.00259353
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [358]	valid_0's rmse: 0.0669683	valid_0's l2: 0.00448476
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [384]	valid_0's rmse: 0.0175088	valid_0's l2: 0.000306558
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [113]	valid_0's rmse: 0.00419528	valid_0's l2: 1.76004e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [126]	valid_0's rmse: 0.00406235	valid_0's l2: 1.65027e-05
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1993]	valid_0's rmse: 0.0334477	valid_0's l2: 0.00111875
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [639]	valid_0's rmse: 0.108704	valid_0's l2: 0.0118165
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [480]	valid_0's rmse: 0.0152897	valid_0's l2: 0.000233774
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [198]	valid_0's rmse: 0.0145843	valid_0's l2: 0.000212701
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [877]	valid_0's rmse: 0.0775567	valid_0's l2: 0.00601504
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [176]	valid_0's rmse: 0.0656952	valid_0's l2: 0.00431586
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [428]	valid_0's rmse: 0.0407094	valid_0's l2: 0.00165726
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [180]	valid_0's rmse: 0.112564	valid_0's l2: 0.0126707
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [134]	valid_0's rmse: 0.00598582	valid_0's l2: 3.583e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1354]	valid_0's rmse: 0.092843	valid_0's l2: 0.00861982
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1987]	valid_0's rmse: 0.352011	valid_0's l2: 0.123912
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [180]	valid_0's rmse: 0.100642	valid_0's l2: 0.0101288
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [426]	valid_0's rmse: 0.106839	valid_0's l2: 0.0114146
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [92]	valid_0's rmse: 0.0244545	valid_0's l2: 0.000598022
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [764]	valid_0's rmse: 0.0210155	valid_0's l2: 0.00044165
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [91]	valid_0's rmse: 0.0297565	valid_0's l2: 0.000885446
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [288]	valid_0's rmse: 0.107754	valid_0's l2: 0.011611
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [94]	valid_0's rmse: 0.0544919	valid_0's l2: 0.00296937
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [267]	valid_0's rmse: 0.00737806	valid_0's l2: 5.44358e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [249]	valid_0's rmse: 0.0270387	valid_0's l2: 0.000731091
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [121]	valid_0's rmse: 0.0575485	valid_0's l2: 0.00331183
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1076]	valid_0's rmse: 0.324716	valid_0's l2: 0.10544
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [288]	valid_0's rmse: 0.0412909	valid_0's l2: 0.00170494
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [149]	valid_0's rmse: 0.00440516	valid_0's l2: 1.94054e-05
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1999]	valid_0's rmse: 0.0598371	valid_0's l2: 0.00358048
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.079438	valid_0's l2: 0.0063104
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [265]	valid_0's rmse: 0.179612	valid_0's l2: 0.0322606
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [57]	valid_0's rmse: 0.0322357	valid_0's l2: 0.00103914
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [103]	valid_0's rmse: 0.00544763	valid_0's l2: 2.96766e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [316]	valid_0's rmse: 0.00624713	valid_0's l2: 3.90267e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [563]	valid_0's rmse: 0.107354	valid_0's l2: 0.011525
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [155]	valid_0's rmse: 0.016419	valid_0's l2: 0.000269583
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	valid_0's rmse: 0.00875705	valid_0's l2: 7.66859e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [179]	valid_0's rmse: 0.00716109	valid_0's l2: 5.12812e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [467]	valid_0's rmse: 0.00976867	valid_0's l2: 9.5427e-05
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.132951	valid_0's l2: 0.0176761
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [289]	valid_0's rmse: 0.524395	valid_0's l2: 0.274991
# ...
# Early stopping, best iteration is:
# [469]	valid_0's rmse: 0.0747063	valid_0's l2: 0.00558102
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1989]	valid_0's rmse: 0.0704238	valid_0's l2: 0.00495951
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [106]	valid_0's rmse: 0.157615	valid_0's l2: 0.0248426
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [241]	valid_0's rmse: 0.0868886	valid_0's l2: 0.00754962
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [126]	valid_0's rmse: 0.0081731	valid_0's l2: 6.67996e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [129]	valid_0's rmse: 0.00643029	valid_0's l2: 4.13487e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [252]	valid_0's rmse: 0.477695	valid_0's l2: 0.228192
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	valid_0's rmse: 0.19433	valid_0's l2: 0.0377643
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [272]	valid_0's rmse: 0.223026	valid_0's l2: 0.0497405
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [185]	valid_0's rmse: 0.0392051	valid_0's l2: 0.00153704
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [577]	valid_0's rmse: 0.0689912	valid_0's l2: 0.00475979
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0612754	valid_0's l2: 0.00375468
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [486]	valid_0's rmse: 0.0552898	valid_0's l2: 0.00305696
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [666]	valid_0's rmse: 0.0258907	valid_0's l2: 0.000670329
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [94]	valid_0's rmse: 0.00265807	valid_0's l2: 7.06535e-06
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [141]	valid_0's rmse: 0.00191897	valid_0's l2: 3.68244e-06
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1987]	valid_0's rmse: 0.52792	valid_0's l2: 0.2787
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [88]	valid_0's rmse: 0.116949	valid_0's l2: 0.0136771
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [213]	valid_0's rmse: 0.31477	valid_0's l2: 0.0990803
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [195]	valid_0's rmse: 0.114814	valid_0's l2: 0.0131822
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [383]	valid_0's rmse: 0.568733	valid_0's l2: 0.323457
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [147]	valid_0's rmse: 0.123843	valid_0's l2: 0.015337
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [341]	valid_0's rmse: 0.267602	valid_0's l2: 0.0716111
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1996]	valid_0's rmse: 0.0951326	valid_0's l2: 0.0090502
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [241]	valid_0's rmse: 0.0550613	valid_0's l2: 0.00303174
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [487]	valid_0's rmse: 0.0319719	valid_0's l2: 0.0010222
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.148739	valid_0's l2: 0.0221232
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [265]	valid_0's rmse: 0.283542	valid_0's l2: 0.0803959
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [443]	valid_0's rmse: 0.0585401	valid_0's l2: 0.00342694
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [156]	valid_0's rmse: 0.00915309	valid_0's l2: 8.37791e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [86]	valid_0's rmse: 0.0107631	valid_0's l2: 0.000115844
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1992]	valid_0's rmse: 0.0340216	valid_0's l2: 0.00115747
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [488]	valid_0's rmse: 0.125913	valid_0's l2: 0.015854
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [471]	valid_0's rmse: 0.016303	valid_0's l2: 0.000265786
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [85]	valid_0's rmse: 0.00571829	valid_0's l2: 3.26989e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [364]	valid_0's rmse: 0.0644974	valid_0's l2: 0.00415991
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0691594	valid_0's l2: 0.00478302
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [447]	valid_0's rmse: 0.0148341	valid_0's l2: 0.00022005
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [241]	valid_0's rmse: 0.00683614	valid_0's l2: 4.67328e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [515]	valid_0's rmse: 0.00190675	valid_0's l2: 3.63571e-06
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.0100406	valid_0's l2: 0.000100813
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1992]	valid_0's rmse: 0.0370302	valid_0's l2: 0.00137124
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1961]	valid_0's rmse: 0.122341	valid_0's l2: 0.0149672
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [473]	valid_0's rmse: 0.0237705	valid_0's l2: 0.000565036
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [225]	valid_0's rmse: 0.00812746	valid_0's l2: 6.60555e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [242]	valid_0's rmse: 0.0887159	valid_0's l2: 0.0078705
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [101]	valid_0's rmse: 0.0610514	valid_0's l2: 0.00372727
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [223]	valid_0's rmse: 0.114047	valid_0's l2: 0.0130066
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [185]	valid_0's rmse: 0.0421571	valid_0's l2: 0.00177722
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [223]	valid_0's rmse: 0.0261019	valid_0's l2: 0.000681311
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [606]	valid_0's rmse: 0.122629	valid_0's l2: 0.015038
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [65]	valid_0's rmse: 0.0537545	valid_0's l2: 0.00288954
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [383]	valid_0's rmse: 0.175262	valid_0's l2: 0.0307168
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [204]	valid_0's rmse: 0.0210755	valid_0's l2: 0.000444177
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [198]	valid_0's rmse: 0.00797891	valid_0's l2: 6.36631e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [521]	valid_0's rmse: 0.114738	valid_0's l2: 0.0131649
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1999]	valid_0's rmse: 0.0298152	valid_0's l2: 0.000888947
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [225]	valid_0's rmse: 0.124061	valid_0's l2: 0.0153911
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [228]	valid_0's rmse: 0.0134506	valid_0's l2: 0.000180918
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [189]	valid_0's rmse: 0.00317254	valid_0's l2: 1.0065e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [242]	valid_0's rmse: 0.00662097	valid_0's l2: 4.38373e-05
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1992]	valid_0's rmse: 0.0337877	valid_0's l2: 0.00114161
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [214]	valid_0's rmse: 0.124221	valid_0's l2: 0.0154309
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [379]	valid_0's rmse: 0.0117631	valid_0's l2: 0.00013837
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [94]	valid_0's rmse: 0.00492886	valid_0's l2: 2.42936e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [302]	valid_0's rmse: 0.0447447	valid_0's l2: 0.00200209
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [178]	valid_0's rmse: 0.0585244	valid_0's l2: 0.0034251
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [216]	valid_0's rmse: 0.10338	valid_0's l2: 0.0106875
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [204]	valid_0's rmse: 0.0480967	valid_0's l2: 0.00231329
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [511]	valid_0's rmse: 0.0194089	valid_0's l2: 0.000376705
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [682]	valid_0's rmse: 0.127871	valid_0's l2: 0.0163509
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1981]	valid_0's rmse: 0.120688	valid_0's l2: 0.0145656
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [122]	valid_0's rmse: 0.0255245	valid_0's l2: 0.000651501
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [419]	valid_0's rmse: 0.224084	valid_0's l2: 0.0502138
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [202]	valid_0's rmse: 0.0405395	valid_0's l2: 0.00164345
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [240]	valid_0's rmse: 0.381308	valid_0's l2: 0.145396
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's rmse: 0.270557	valid_0's l2: 0.0732008
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1950]	valid_0's rmse: 0.0891247	valid_0's l2: 0.00794322
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [637]	valid_0's rmse: 0.0749211	valid_0's l2: 0.00561317
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [216]	valid_0's rmse: 0.0250113	valid_0's l2: 0.000625565
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [292]	valid_0's rmse: 0.242285	valid_0's l2: 0.0587019
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [301]	valid_0's rmse: 0.0356719	valid_0's l2: 0.00127249
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [251]	valid_0's rmse: 0.248685	valid_0's l2: 0.061844
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [209]	valid_0's rmse: 0.0232842	valid_0's l2: 0.000542155
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [137]	valid_0's rmse: 0.00521166	valid_0's l2: 2.71614e-05
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [304]	valid_0's rmse: 0.0642126	valid_0's l2: 0.00412326
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1982]	valid_0's rmse: 0.215829	valid_0's l2: 0.046582
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [309]	valid_0's rmse: 0.0778154	valid_0's l2: 0.00605523
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [174]	valid_0's rmse: 0.210219	valid_0's l2: 0.0441918
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [342]	valid_0's rmse: 0.0289357	valid_0's l2: 0.000837277
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [227]	valid_0's rmse: 0.0496673	valid_0's l2: 0.00246684
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1980]	valid_0's rmse: 0.209784	valid_0's l2: 0.0440094
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [296]	valid_0's rmse: 0.134482	valid_0's l2: 0.0180853
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [189]	valid_0's rmse: 0.256335	valid_0's l2: 0.0657075
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1059]	valid_0's rmse: 0.0483566	valid_0's l2: 0.00233836
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [336]	valid_0's rmse: 0.0421895	valid_0's l2: 0.00177996
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [1982]	valid_0's rmse: 0.60728	valid_0's l2: 0.368789
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [551]	valid_0's rmse: 0.0429123	valid_0's l2: 0.00184147
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [231]	valid_0's rmse: 0.0321004	valid_0's l2: 0.00103044
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [387]	valid_0's rmse: 0.0723557	valid_0's l2: 0.00523534
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [130]	valid_0's rmse: 0.0212854	valid_0's l2: 0.000453069
# Done. elapsed=116.2 min
# Saved to: /kaggle/working/models_price
# Examples: ['cv_price_metrics.csv', 'meta_price.json', 'price__FX_AUDCAD.txt', 'price__FX_AUDCHF.txt', 'price__FX_AUDJPY.txt', 'price__FX_AUDUSD.txt', 'price__FX_CADCHF.txt', 'price__FX_CADJPY.txt', 'price__FX_CADUSD.txt', 'price__FX_CHFJPY.txt']
