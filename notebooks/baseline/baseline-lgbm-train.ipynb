# %% [markdown]
# ## Training Code (Train Notebook)
#
# ### Overview
# - **Objective**: Train a model for each target using LightGBM (GPU) and save the trained model.
# - **Outcome**: Output a set of `.pkl` files and a meta information file (`meta.json`) to `/kaggle/working/models`.
# - Publish this by selecting "Create Dataset" in Kaggle Notebook → it can be used in the submission notebook.
# - Combine train.csv and train_labels.csv without preprocessing, and train each target_* using independent regression.
#
# **This is a baseline implementation that can be submitted simply without preprocessing, using raw features as is.** The goal is to "first submit and understand how the score works."
#
# ### Steps
# 1. **Loading Data**
# - Load `train.csv`, `test.csv`, and `train_labels.csv`.
# - Confirm that `date_id` is the key.
#
# 2. **Preprocessing**
# - Quantify object data (return NaN for failures)
# - Category data → `.cat.codes`
# - Intersect numeric columns and define `feat_cols` as `feat_cols`.
#
# 3. **Define Features and Objective Variables**
# - Build training data using `train.merge(labels, on="date_id")`.
# - `label_cols = target_0 .. target_423`
#
# 4. **LightGBM Settings**
# - GPU Training (`device_type="gpu"`)
# - Early Stopping
#
# 5. **Training Loop**
# - Train for each target.
# - Skip samples with insufficient samples (<20 lines) and output a `.skip` file.
# - Save the training model as `joblib.dump`.
#
# 6. **Save Meta Information**
# - Save the feature list, target list, and LGBM parameters used in `meta.json`.
# - Create a new model by selecting ShowVersions → Notebook → Output → New Model.
#
# 7. **Verify**
# - Output and verify the list of files saved in `/kaggle/working/models`.
# - Submission Notebook -> https://www.kaggle.com/code/shunyafukuda/baseline-lgbm-submit/

# %%
# ---------------- Librarys ----------------
import os, sys, time, json, warnings, joblib
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# Install & import
# !pip -q install --upgrade lightgbm
import lightgbm as lgb

# %%
# =========================================================
# TRAIN NOTEBOOK: LightGBM(GPU) per-target -> save models + meta
# 1) Train and save to /kaggle/working/models
# 2) After execution, publish this folder with "Create Dataset"
# =========================================================


# ---------------- Paths ----------------
DATA_PATH  = "/kaggle/input/mitsui-commodity-prediction-challenge"
TRAIN_PATH = f"{DATA_PATH}/train.csv"
TEST_PATH  = f"{DATA_PATH}/test.csv"
LABELS_PATH= f"{DATA_PATH}/train_labels.csv"

MODEL_OUTPUT_DIR = "/kaggle/working/models"
os.makedirs(MODEL_OUTPUT_DIR, exist_ok=True)

# ---------------- Preprocess helper ----------------
def preprocess_for_lgbm(df: pd.DataFrame) -> pd.DataFrame:
    """object→numeric（失敗はNaN）、category→codes"""
    df = df.copy()
    obj_cols = df.select_dtypes(include=["object"]).columns
    if len(obj_cols) > 0:
        df[obj_cols] = df[obj_cols].apply(pd.to_numeric, errors="coerce")
    for c in df.select_dtypes(include=["category"]).columns:
        df[c] = df[c].cat.codes
    return df

# ---------------- Load ----------------
train_raw  = pd.read_csv(TRAIN_PATH)
test_raw   = pd.read_csv(TEST_PATH)
labels     = pd.read_csv(LABELS_PATH)

for name, df_ in [("train", train_raw), ("test", test_raw), ("labels", labels)]:
    assert "date_id" in df_.columns, f"{name}.csv に date_id がありません"

train = preprocess_for_lgbm(train_raw)
test  = preprocess_for_lgbm(test_raw)

# ---------------- Feature/Label schema ----------------
df = train.merge(labels, on="date_id", how="inner")

label_cols = [c for c in labels.columns if c != "date_id"]  # target_0..423
num_train_cols = df.select_dtypes(include=[np.number]).columns.tolist()
num_test_cols  = test.select_dtypes(include=[np.number]).columns.tolist()
feat_cols = sorted(set(num_train_cols).intersection(num_test_cols))
feat_cols = [c for c in feat_cols if c not in label_cols]  # exclude targets

X = df[feat_cols]
print(f"#features={len(feat_cols)} | #train_rows={len(X)} | #test_rows={len(test)}")

# ---------------- LGBM params (GPU) ----------------
lgb_params = dict(
    n_estimators=1000,
    learning_rate=0.03,
    num_leaves=31,
    feature_fraction=0.8,
    bagging_fraction=0.8,
    bagging_freq=1,
    max_bin=255,
    random_state=42,
    verbosity=-1,
    device_type="gpu",
    gpu_platform_id=0,
    gpu_device_id=0,
)
callbacks = [lgb.log_evaluation(period=0), lgb.early_stopping(stopping_rounds=50)]

# ---------------- Train & Save ----------------
t0 = time.time()
for i, tgt in enumerate(label_cols, 1):
    y_full = df[tgt].values
    mask   = np.isfinite(y_full)
    Xc, yc = X.loc[mask], y_full[mask]

    print(f"[{i:03d}/{len(label_cols)}] {tgt}: train_rows={len(Xc)}, features={Xc.shape[1]}")

    if len(yc) < 20:
        # Skip learning → Create a flag file for 0 output because it cannot be saved with empty dummy (None)
        with open(os.path.join(MODEL_OUTPUT_DIR, f"{tgt}.skip"), "w") as f:
            f.write("too_few_samples")
        continue

    n   = len(Xc)
    cut = max(int(n*0.9), n-1)   # Simple verification of the last 10%
    X_tr, y_tr = Xc.iloc[:cut], yc[:cut]
    X_va, y_va = Xc.iloc[cut:], yc[cut:]

    model = lgb.LGBMRegressor(**lgb_params)
    model.fit(
        X_tr, y_tr,
        eval_set=[(X_va, y_va)] if len(X_va) > 0 else None,
        eval_metric="rmse",
        callbacks=callbacks
    )

    joblib.dump(model, os.path.join(MODEL_OUTPUT_DIR, f"{tgt}.pkl"))

print(f"Training finished in {time.time()-t0:.1f}s (GPU)")

# ---------------- Save meta (schema & params) ----------------
meta = {
    "feat_cols": feat_cols,
    "label_cols": label_cols,
    "lgb_params": {k: (str(v) if k in ("device_type",) else v) for k,v in lgb_params.items()},
    "note": "Use these columns/order in the submission notebook."
}
with open(os.path.join(MODEL_OUTPUT_DIR, "meta.json"), "w") as f:
    json.dump(meta, f)

# For confirmation
print("Saved models to:", MODEL_OUTPUT_DIR)
print("Example files:", sorted(os.listdir(MODEL_OUTPUT_DIR))[:8])
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 36.7 MB/s eta 0:00:00a 0:00:01
# #features=558 | #train_rows=1917 | #test_rows=90
# [001/424] target_0: train_rows=1787, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [162]	valid_0's rmse: 4.71253e-06	valid_0's l2: 2.22079e-11
# [002/424] target_1: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [129]	valid_0's rmse: 0.00918688	valid_0's l2: 8.43988e-05
# [003/424] target_2: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	valid_0's rmse: 0.00973496	valid_0's l2: 9.47695e-05
# [004/424] target_3: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	valid_0's rmse: 1.09984e-06	valid_0's l2: 1.20965e-12
# [005/424] target_4: train_rows=1631, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [135]	valid_0's rmse: 3.09473e-06	valid_0's l2: 9.57735e-12
# [006/424] target_5: train_rows=1631, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [88]	valid_0's rmse: 0.00423995	valid_0's l2: 1.79772e-05
# [007/424] target_6: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [80]	valid_0's rmse: 0.00634201	valid_0's l2: 4.02211e-05
# [008/424] target_7: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	valid_0's rmse: 0.0021339	valid_0's l2: 4.55352e-06
# [009/424] target_8: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	valid_0's rmse: 0.0031063	valid_0's l2: 9.64912e-06
# [010/424] target_9: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [73]	valid_0's rmse: 0.00212637	valid_0's l2: 4.52143e-06
# [011/424] target_10: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	valid_0's rmse: 5.34828e-05	valid_0's l2: 2.86041e-09
# [012/424] target_11: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 0.0156123	valid_0's l2: 0.000243745
# [013/424] target_12: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0157013	valid_0's l2: 0.000246529
# [014/424] target_13: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [173]	valid_0's rmse: 0.00323698	valid_0's l2: 1.04781e-05
# [015/424] target_14: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0153155	valid_0's l2: 0.000234565
# [016/424] target_15: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	valid_0's rmse: 0.00257788	valid_0's l2: 6.64548e-06
# [017/424] target_16: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	valid_0's rmse: 0.000894923	valid_0's l2: 8.00887e-07
# [018/424] target_17: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	valid_0's rmse: 2.76502e-05	valid_0's l2: 7.64534e-10
# [019/424] target_18: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	valid_0's rmse: 0.00688844	valid_0's l2: 4.74506e-05
# [020/424] target_19: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [52]	valid_0's rmse: 0.0124717	valid_0's l2: 0.000155542
# [021/424] target_20: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	valid_0's rmse: 0.00275934	valid_0's l2: 7.61397e-06
# [022/424] target_21: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	valid_0's rmse: 0.00973789	valid_0's l2: 9.48265e-05
# [023/424] target_22: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	valid_0's rmse: 4.04739e-06	valid_0's l2: 1.63813e-11
# [024/424] target_23: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [60]	valid_0's rmse: 0.00936073	valid_0's l2: 8.76232e-05
# [025/424] target_24: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	valid_0's rmse: 0.0992749	valid_0's l2: 0.00985551
# [026/424] target_25: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 8.24201e-05	valid_0's l2: 6.79307e-09
# [027/424] target_26: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	valid_0's rmse: 0.00949104	valid_0's l2: 9.00798e-05
# [028/424] target_27: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [55]	valid_0's rmse: 0.00434728	valid_0's l2: 1.88989e-05
# [029/424] target_28: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [362]	valid_0's rmse: 0.00224699	valid_0's l2: 5.04895e-06
# [030/424] target_29: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	valid_0's rmse: 0.005613	valid_0's l2: 3.15058e-05
# [031/424] target_30: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	valid_0's rmse: 0.102411	valid_0's l2: 0.010488
# [032/424] target_31: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	valid_0's rmse: 0.0186092	valid_0's l2: 0.000346304
# [033/424] target_32: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	valid_0's rmse: 0.0280799	valid_0's l2: 0.000788482
# [034/424] target_33: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	valid_0's rmse: 0.00835577	valid_0's l2: 6.98189e-05
# [035/424] target_34: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0128187	valid_0's l2: 0.000164318
# [036/424] target_35: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [112]	valid_0's rmse: 0.00158448	valid_0's l2: 2.51057e-06
# [037/424] target_36: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	valid_0's rmse: 1.64234e-05	valid_0's l2: 2.69728e-10
# [038/424] target_37: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0132757	valid_0's l2: 0.000176245
# [039/424] target_38: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	valid_0's rmse: 4.24956e-05	valid_0's l2: 1.80588e-09
# [040/424] target_39: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [83]	valid_0's rmse: 1.73247e-07	valid_0's l2: 3.00144e-14
# [041/424] target_40: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	valid_0's rmse: 0.00376783	valid_0's l2: 1.41966e-05
# [042/424] target_41: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.0295005	valid_0's l2: 0.000870279
# [043/424] target_42: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	valid_0's rmse: 0.00169357	valid_0's l2: 2.86819e-06
# [044/424] target_43: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	valid_0's rmse: 2.18862e-05	valid_0's l2: 4.79007e-10
# [045/424] target_44: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	valid_0's rmse: 0.00297329	valid_0's l2: 8.84046e-06
# [046/424] target_45: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00940542	valid_0's l2: 8.84618e-05
# [047/424] target_46: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [85]	valid_0's rmse: 0.00279366	valid_0's l2: 7.80456e-06
# [048/424] target_47: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.0227383	valid_0's l2: 0.000517029
# [049/424] target_48: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	valid_0's rmse: 0.00598536	valid_0's l2: 3.58245e-05
# [050/424] target_49: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [94]	valid_0's rmse: 0.043159	valid_0's l2: 0.0018627
# [051/424] target_50: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	valid_0's rmse: 0.00174771	valid_0's l2: 3.05448e-06
# [052/424] target_51: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	valid_0's rmse: 0.0054179	valid_0's l2: 2.93537e-05
# [053/424] target_52: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0058163	valid_0's l2: 3.38294e-05
# [054/424] target_53: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [47]	valid_0's rmse: 0.00668401	valid_0's l2: 4.4676e-05
# [055/424] target_54: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [116]	valid_0's rmse: 1.23111e-05	valid_0's l2: 1.51564e-10
# [056/424] target_55: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	valid_0's rmse: 0.00200703	valid_0's l2: 4.02816e-06
# [057/424] target_56: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [54]	valid_0's rmse: 0.012757	valid_0's l2: 0.000162742
# [058/424] target_57: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	valid_0's rmse: 0.00357424	valid_0's l2: 1.27752e-05
# [059/424] target_58: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	valid_0's rmse: 0.0174402	valid_0's l2: 0.000304162
# [060/424] target_59: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [96]	valid_0's rmse: 0.000152587	valid_0's l2: 2.32829e-08
# [061/424] target_60: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [52]	valid_0's rmse: 0.000945249	valid_0's l2: 8.93496e-07
# [062/424] target_61: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00119188	valid_0's l2: 1.42057e-06
# [063/424] target_62: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	valid_0's rmse: 0.00788786	valid_0's l2: 6.22183e-05
# [064/424] target_63: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	valid_0's rmse: 0.00863448	valid_0's l2: 7.45542e-05
# [065/424] target_64: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	valid_0's rmse: 0.00106952	valid_0's l2: 1.14388e-06
# [066/424] target_65: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	valid_0's rmse: 0.00193903	valid_0's l2: 3.75984e-06
# [067/424] target_66: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [156]	valid_0's rmse: 0.0082197	valid_0's l2: 6.75634e-05
# [068/424] target_67: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [140]	valid_0's rmse: 0.000141098	valid_0's l2: 1.99088e-08
# [069/424] target_68: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 2.45122e-05	valid_0's l2: 6.0085e-10
# [070/424] target_69: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [62]	valid_0's rmse: 0.00336849	valid_0's l2: 1.13468e-05
# [071/424] target_70: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	valid_0's rmse: 0.0124651	valid_0's l2: 0.000155378
# [072/424] target_71: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [116]	valid_0's rmse: 0.00418803	valid_0's l2: 1.75396e-05
# [073/424] target_72: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [231]	valid_0's rmse: 1.70792e-05	valid_0's l2: 2.91699e-10
# [074/424] target_73: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [77]	valid_0's rmse: 2.16109e-05	valid_0's l2: 4.67032e-10
# [075/424] target_74: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	valid_0's rmse: 0.00673975	valid_0's l2: 4.54242e-05
# [076/424] target_75: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	valid_0's rmse: 0.00175767	valid_0's l2: 3.08941e-06
# [077/424] target_76: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	valid_0's rmse: 0.00259161	valid_0's l2: 6.71646e-06
# [078/424] target_77: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	valid_0's rmse: 0.00351459	valid_0's l2: 1.23524e-05
# [079/424] target_78: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [134]	valid_0's rmse: 0.0565435	valid_0's l2: 0.00319717
# [080/424] target_79: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	valid_0's rmse: 0.000745504	valid_0's l2: 5.55777e-07
# [081/424] target_80: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	valid_0's rmse: 0.00295105	valid_0's l2: 8.70869e-06
# [082/424] target_81: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	valid_0's rmse: 5.20784e-05	valid_0's l2: 2.71216e-09
# [083/424] target_82: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [370]	valid_0's rmse: 0.16518	valid_0's l2: 0.0272845
# [084/424] target_83: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0101382	valid_0's l2: 0.000102783
# [085/424] target_84: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	valid_0's rmse: 9.98439e-05	valid_0's l2: 9.96881e-09
# [086/424] target_85: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [77]	valid_0's rmse: 0.0143258	valid_0's l2: 0.00020523
# [087/424] target_86: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	valid_0's rmse: 1.19393e-06	valid_0's l2: 1.42547e-12
# [088/424] target_87: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [85]	valid_0's rmse: 0.00241987	valid_0's l2: 5.85579e-06
# [089/424] target_88: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [60]	valid_0's rmse: 0.0117093	valid_0's l2: 0.000137108
# [090/424] target_89: train_rows=1831, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	valid_0's rmse: 0.0078662	valid_0's l2: 6.18771e-05
# [091/424] target_90: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	valid_0's rmse: 2.48176e-05	valid_0's l2: 6.15913e-10
# [092/424] target_91: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	valid_0's rmse: 0.0178565	valid_0's l2: 0.000318854
# [093/424] target_92: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [39]	valid_0's rmse: 0.00510397	valid_0's l2: 2.60505e-05
# [094/424] target_93: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	valid_0's rmse: 2.60524e-05	valid_0's l2: 6.7873e-10
# [095/424] target_94: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.00525926	valid_0's l2: 2.76598e-05
# [096/424] target_95: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	valid_0's rmse: 0.00384659	valid_0's l2: 1.47963e-05
# [097/424] target_96: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	valid_0's rmse: 0.0144858	valid_0's l2: 0.000209839
# [098/424] target_97: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00959031	valid_0's l2: 9.1974e-05
# [099/424] target_98: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	valid_0's rmse: 0.0104487	valid_0's l2: 0.000109176
# [100/424] target_99: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	valid_0's rmse: 0.0177789	valid_0's l2: 0.000316088
# [101/424] target_100: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	valid_0's rmse: 0.0160198	valid_0's l2: 0.000256633
# [102/424] target_101: train_rows=1712, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	valid_0's rmse: 0.00739861	valid_0's l2: 5.47395e-05
# [103/424] target_102: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.00170852	valid_0's l2: 2.91904e-06
# [104/424] target_103: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	valid_0's rmse: 0.0158497	valid_0's l2: 0.000251214
# [105/424] target_104: train_rows=1587, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	valid_0's rmse: 0.0212769	valid_0's l2: 0.000452707
# [106/424] target_105: train_rows=1744, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	valid_0's rmse: 0.00831783	valid_0's l2: 6.91863e-05
# [107/424] target_106: train_rows=1787, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	valid_0's rmse: 0.00631448	valid_0's l2: 3.98727e-05
# [108/424] target_107: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [114]	valid_0's rmse: 0.00307224	valid_0's l2: 9.43863e-06
# [109/424] target_108: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	valid_0's rmse: 0.00416192	valid_0's l2: 1.73216e-05
# [110/424] target_109: train_rows=1605, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [98]	valid_0's rmse: 0.00763006	valid_0's l2: 5.82178e-05
# [111/424] target_110: train_rows=1605, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.0269829	valid_0's l2: 0.000728079
# [112/424] target_111: train_rows=1605, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	valid_0's rmse: 0.00436729	valid_0's l2: 1.90732e-05
# [113/424] target_112: train_rows=1605, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.00448227	valid_0's l2: 2.00907e-05
# [114/424] target_113: train_rows=1701, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	valid_0's rmse: 0.000448063	valid_0's l2: 2.0076e-07
# [115/424] target_114: train_rows=1701, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0137201	valid_0's l2: 0.000188242
# [116/424] target_115: train_rows=1701, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	valid_0's rmse: 0.00408646	valid_0's l2: 1.66992e-05
# [117/424] target_116: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	valid_0's rmse: 0.00393221	valid_0's l2: 1.54623e-05
# [118/424] target_117: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	valid_0's rmse: 0.00132321	valid_0's l2: 1.75088e-06
# [119/424] target_118: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	valid_0's rmse: 4.9719e-07	valid_0's l2: 2.47198e-13
# [120/424] target_119: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [64]	valid_0's rmse: 1.44528e-05	valid_0's l2: 2.08883e-10
# [121/424] target_120: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	valid_0's rmse: 0.00707439	valid_0's l2: 5.00469e-05
# [122/424] target_121: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	valid_0's rmse: 0.0148177	valid_0's l2: 0.000219565
# [123/424] target_122: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.0318598	valid_0's l2: 0.00101505
# [124/424] target_123: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.024125	valid_0's l2: 0.000582014
# [125/424] target_124: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [52]	valid_0's rmse: 0.016212	valid_0's l2: 0.000262828
# [126/424] target_125: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [116]	valid_0's rmse: 0.000691395	valid_0's l2: 4.78027e-07
# [127/424] target_126: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	valid_0's rmse: 0.000215525	valid_0's l2: 4.6451e-08
# [128/424] target_127: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [52]	valid_0's rmse: 0.00207021	valid_0's l2: 4.28577e-06
# [129/424] target_128: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.0361384	valid_0's l2: 0.00130598
# [130/424] target_129: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	valid_0's rmse: 0.00678712	valid_0's l2: 4.60651e-05
# [131/424] target_130: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.0314359	valid_0's l2: 0.000988214
# [132/424] target_131: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	valid_0's rmse: 3.21152e-05	valid_0's l2: 1.03139e-09
# [133/424] target_132: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [323]	valid_0's rmse: 0.00154567	valid_0's l2: 2.3891e-06
# [134/424] target_133: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	valid_0's rmse: 0.00491174	valid_0's l2: 2.41252e-05
# [135/424] target_134: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	valid_0's rmse: 0.00290326	valid_0's l2: 8.42889e-06
# [136/424] target_135: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.023782	valid_0's l2: 0.000565586
# [137/424] target_136: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	valid_0's rmse: 6.84009e-05	valid_0's l2: 4.67869e-09
# [138/424] target_137: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.0046019	valid_0's l2: 2.11775e-05
# [139/424] target_138: train_rows=1701, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	valid_0's rmse: 0.0110638	valid_0's l2: 0.000122408
# [140/424] target_139: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	valid_0's rmse: 0.00229865	valid_0's l2: 5.28381e-06
# [141/424] target_140: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [98]	valid_0's rmse: 0.0389187	valid_0's l2: 0.00151466
# [142/424] target_141: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [54]	valid_0's rmse: 2.96394e-06	valid_0's l2: 8.78492e-12
# [143/424] target_142: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	valid_0's rmse: 0.0023129	valid_0's l2: 5.34952e-06
# [144/424] target_143: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.02332	valid_0's l2: 0.000543824
# [145/424] target_144: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.010518	valid_0's l2: 0.000110629
# [146/424] target_145: train_rows=1701, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	valid_0's rmse: 0.00980799	valid_0's l2: 9.61966e-05
# [147/424] target_146: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	valid_0's rmse: 0.0104496	valid_0's l2: 0.000109195
# [148/424] target_147: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0406147	valid_0's l2: 0.00164955
# [149/424] target_148: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0174109	valid_0's l2: 0.000303141
# [150/424] target_149: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0304945	valid_0's l2: 0.000929915
# [151/424] target_150: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [362]	valid_0's rmse: 0.00212256	valid_0's l2: 4.50526e-06
# [152/424] target_151: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	valid_0's rmse: 0.00110371	valid_0's l2: 1.21818e-06
# [153/424] target_152: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [78]	valid_0's rmse: 5.61637e-05	valid_0's l2: 3.15436e-09
# [154/424] target_153: train_rows=1701, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	valid_0's rmse: 0.00647678	valid_0's l2: 4.19487e-05
# [155/424] target_154: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0137075	valid_0's l2: 0.000187894
# [156/424] target_155: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.0140874	valid_0's l2: 0.000198455
# [157/424] target_156: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	valid_0's rmse: 5.95765e-05	valid_0's l2: 3.54936e-09
# [158/424] target_157: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.0340697	valid_0's l2: 0.00116075
# [159/424] target_158: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0107163	valid_0's l2: 0.000114838
# [160/424] target_159: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.0354898	valid_0's l2: 0.00125952
# [161/424] target_160: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0112403	valid_0's l2: 0.000126343
# [162/424] target_161: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [125]	valid_0's rmse: 0.00118983	valid_0's l2: 1.41569e-06
# [163/424] target_162: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	valid_0's rmse: 0.000367552	valid_0's l2: 1.35094e-07
# [164/424] target_163: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	valid_0's rmse: 0.0243514	valid_0's l2: 0.000592989
# [165/424] target_164: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [14]	valid_0's rmse: 0.0125458	valid_0's l2: 0.000157398
# [166/424] target_165: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00638855	valid_0's l2: 4.08136e-05
# [167/424] target_166: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	valid_0's rmse: 0.0201747	valid_0's l2: 0.000407017
# [168/424] target_167: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.012539	valid_0's l2: 0.000157227
# [169/424] target_168: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.00620827	valid_0's l2: 3.85427e-05
# [170/424] target_169: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	valid_0's rmse: 0.0037446	valid_0's l2: 1.4022e-05
# [171/424] target_170: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00921111	valid_0's l2: 8.48446e-05
# [172/424] target_171: train_rows=1701, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [100]	valid_0's rmse: 0.000114125	valid_0's l2: 1.30244e-08
# [173/424] target_172: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	valid_0's rmse: 1.14128e-05	valid_0's l2: 1.30252e-10
# [174/424] target_173: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	valid_0's rmse: 2.45324e-05	valid_0's l2: 6.01838e-10
# [175/424] target_174: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00578891	valid_0's l2: 3.35114e-05
# [176/424] target_175: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0349821	valid_0's l2: 0.00122375
# [177/424] target_176: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.00684369	valid_0's l2: 4.68361e-05
# [178/424] target_177: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.0132889	valid_0's l2: 0.000176594
# [179/424] target_178: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [21]	valid_0's rmse: 4.42283e-05	valid_0's l2: 1.95615e-09
# [180/424] target_179: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.0112615	valid_0's l2: 0.000126821
# [181/424] target_180: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0293595	valid_0's l2: 0.000861982
# [182/424] target_181: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	valid_0's rmse: 0.0126814	valid_0's l2: 0.000160817
# [183/424] target_182: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	valid_0's rmse: 6.24247e-05	valid_0's l2: 3.89684e-09
# [184/424] target_183: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0149043	valid_0's l2: 0.00022214
# [185/424] target_184: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	valid_0's rmse: 0.0217558	valid_0's l2: 0.000473316
# [186/424] target_185: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [89]	valid_0's rmse: 7.75962e-05	valid_0's l2: 6.02117e-09
# [187/424] target_186: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 0.0143118	valid_0's l2: 0.000204826
# [188/424] target_187: train_rows=1701, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0173342	valid_0's l2: 0.000300475
# [189/424] target_188: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.010039	valid_0's l2: 0.000100782
# [190/424] target_189: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [343]	valid_0's rmse: 0.000545708	valid_0's l2: 2.97798e-07
# [191/424] target_190: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.0019969	valid_0's l2: 3.9876e-06
# [192/424] target_191: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00842078	valid_0's l2: 7.09096e-05
# [193/424] target_192: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	valid_0's rmse: 0.00390826	valid_0's l2: 1.52745e-05
# [194/424] target_193: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	valid_0's rmse: 0.00029104	valid_0's l2: 8.47043e-08
# [195/424] target_194: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.022227	valid_0's l2: 0.00049404
# [196/424] target_195: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0145822	valid_0's l2: 0.000212642
# [197/424] target_196: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	valid_0's rmse: 0.0038864	valid_0's l2: 1.51041e-05
# [198/424] target_197: train_rows=1701, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	valid_0's rmse: 9.59676e-05	valid_0's l2: 9.20978e-09
# [199/424] target_198: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	valid_0's rmse: 0.00927105	valid_0's l2: 8.59524e-05
# [200/424] target_199: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.0329771	valid_0's l2: 0.00108749
# [201/424] target_200: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [142]	valid_0's rmse: 0.000764853	valid_0's l2: 5.84999e-07
# [202/424] target_201: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	valid_0's rmse: 8.97714e-06	valid_0's l2: 8.0589e-11
# [203/424] target_202: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.0124392	valid_0's l2: 0.000154734
# [204/424] target_203: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	valid_0's rmse: 0.0146046	valid_0's l2: 0.000213294
# [205/424] target_204: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0178637	valid_0's l2: 0.000319113
# [206/424] target_205: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [279]	valid_0's rmse: 0.00720088	valid_0's l2: 5.18527e-05
# [207/424] target_206: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [132]	valid_0's rmse: 5.31471e-05	valid_0's l2: 2.82461e-09
# [208/424] target_207: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.0228237	valid_0's l2: 0.000520922
# [209/424] target_208: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0045608	valid_0's l2: 2.08009e-05
# [210/424] target_209: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	valid_0's rmse: 0.0129094	valid_0's l2: 0.000166653
# [211/424] target_210: train_rows=1577, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [5]	valid_0's rmse: 0.0323786	valid_0's l2: 0.00104837
# [212/424] target_211: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	valid_0's rmse: 0.00530626	valid_0's l2: 2.81564e-05
# [213/424] target_212: train_rows=1917, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	valid_0's rmse: 0.00290497	valid_0's l2: 8.43888e-06
# [214/424] target_213: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	valid_0's rmse: 0.00276631	valid_0's l2: 7.65248e-06
# [215/424] target_214: train_rows=1606, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	valid_0's rmse: 8.40063e-06	valid_0's l2: 7.05706e-11
# [216/424] target_215: train_rows=1606, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0011344	valid_0's l2: 1.28686e-06
# [217/424] target_216: train_rows=1606, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0131808	valid_0's l2: 0.000173733
# [218/424] target_217: train_rows=1606, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	valid_0's rmse: 2.93626e-06	valid_0's l2: 8.62164e-12
# [219/424] target_218: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [25]	valid_0's rmse: 8.04926e-07	valid_0's l2: 6.47905e-13
# [220/424] target_219: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00659258	valid_0's l2: 4.3462e-05
# [221/424] target_220: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [15]	valid_0's rmse: 0.0015502	valid_0's l2: 2.40311e-06
# [222/424] target_221: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	valid_0's rmse: 3.97961e-05	valid_0's l2: 1.58373e-09
# [223/424] target_222: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	valid_0's rmse: 0.00946741	valid_0's l2: 8.96318e-05
# [224/424] target_223: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [296]	valid_0's rmse: 0.00796967	valid_0's l2: 6.35156e-05
# [225/424] target_224: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 0.000979968	valid_0's l2: 9.60338e-07
# [226/424] target_225: train_rows=1573, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	valid_0's rmse: 1.75981e-05	valid_0's l2: 3.09692e-10
# [227/424] target_226: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	valid_0's rmse: 0.000757666	valid_0's l2: 5.74058e-07
# [228/424] target_227: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00262955	valid_0's l2: 6.91455e-06
# [229/424] target_228: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00332496	valid_0's l2: 1.10554e-05
# [230/424] target_229: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [182]	valid_0's rmse: 0.00721538	valid_0's l2: 5.20617e-05
# [231/424] target_230: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.00637881	valid_0's l2: 4.06893e-05
# [232/424] target_231: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [8]	valid_0's rmse: 0.0241833	valid_0's l2: 0.000584831
# [233/424] target_232: train_rows=1573, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.0104703	valid_0's l2: 0.000109628
# [234/424] target_233: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# ...
# Early stopping, best iteration is:
# [7]	valid_0's rmse: 0.00983715	valid_0's l2: 9.67695e-05
# [349/424] target_348: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [149]	valid_0's rmse: 4.09885e-06	valid_0's l2: 1.68005e-11
# [350/424] target_349: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.000176668	valid_0's l2: 3.12117e-08
# [351/424] target_350: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [94]	valid_0's rmse: 6.36602e-05	valid_0's l2: 4.05262e-09
# [352/424] target_351: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [122]	valid_0's rmse: 2.04355e-05	valid_0's l2: 4.17609e-10
# [353/424] target_352: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.00895248	valid_0's l2: 8.01469e-05
# [354/424] target_353: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	valid_0's rmse: 0.011317	valid_0's l2: 0.000128075
# [355/424] target_354: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.00696433	valid_0's l2: 4.85019e-05
# [356/424] target_355: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	valid_0's rmse: 0.0123738	valid_0's l2: 0.000153111
# [357/424] target_356: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00158412	valid_0's l2: 2.50944e-06
# [358/424] target_357: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	valid_0's rmse: 0.0176529	valid_0's l2: 0.000311624
# [359/424] target_358: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00774253	valid_0's l2: 5.99467e-05
# [360/424] target_359: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [354]	valid_0's rmse: 0.00310707	valid_0's l2: 9.65391e-06
# [361/424] target_360: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	valid_0's rmse: 0.0133276	valid_0's l2: 0.000177625
# [362/424] target_361: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	valid_0's rmse: 0.0257345	valid_0's l2: 0.000662267
# [363/424] target_362: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0101898	valid_0's l2: 0.000103832
# [364/424] target_363: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	valid_0's rmse: 5.20708e-06	valid_0's l2: 2.71136e-11
# [365/424] target_364: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.000503393	valid_0's l2: 2.53405e-07
# [366/424] target_365: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [12]	valid_0's rmse: 0.00610024	valid_0's l2: 3.7213e-05
# [367/424] target_366: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [10]	valid_0's rmse: 5.98923e-05	valid_0's l2: 3.58709e-09
# [368/424] target_367: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	valid_0's rmse: 0.00766356	valid_0's l2: 5.87301e-05
# [369/424] target_368: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 9.93444e-05	valid_0's l2: 9.86931e-09
# [370/424] target_369: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	valid_0's rmse: 0.000454072	valid_0's l2: 2.06181e-07
# [371/424] target_370: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	valid_0's rmse: 0.000220696	valid_0's l2: 4.87066e-08
# [372/424] target_371: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.000173023	valid_0's l2: 2.99371e-08
# [373/424] target_372: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [109]	valid_0's rmse: 6.11342e-06	valid_0's l2: 3.73739e-11
# [374/424] target_373: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00670509	valid_0's l2: 4.49582e-05
# [375/424] target_374: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.00666427	valid_0's l2: 4.44124e-05
# [376/424] target_375: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00512165	valid_0's l2: 2.62313e-05
# [377/424] target_376: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	valid_0's rmse: 0.0155321	valid_0's l2: 0.000241246
# [378/424] target_377: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [66]	valid_0's rmse: 0.00955203	valid_0's l2: 9.12413e-05
# [379/424] target_378: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [138]	valid_0's rmse: 0.00921747	valid_0's l2: 8.49618e-05
# [380/424] target_379: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	valid_0's rmse: 7.31837e-06	valid_0's l2: 5.35586e-11
# [381/424] target_380: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [58]	valid_0's rmse: 0.0134188	valid_0's l2: 0.000180065
# [382/424] target_381: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0145299	valid_0's l2: 0.000211119
# [383/424] target_382: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.00142044	valid_0's l2: 2.01765e-06
# [384/424] target_383: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0019351	valid_0's l2: 3.74459e-06
# [385/424] target_384: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.00180442	valid_0's l2: 3.25593e-06
# [386/424] target_385: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	valid_0's rmse: 0.010184	valid_0's l2: 0.000103714
# [387/424] target_386: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	valid_0's rmse: 0.0130002	valid_0's l2: 0.000169006
# [388/424] target_387: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	valid_0's rmse: 4.2123e-05	valid_0's l2: 1.77434e-09
# [389/424] target_388: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [186]	valid_0's rmse: 0.00585573	valid_0's l2: 3.42896e-05
# [390/424] target_389: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	valid_0's rmse: 0.00921498	valid_0's l2: 8.49159e-05
# [391/424] target_390: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [194]	valid_0's rmse: 2.7147e-05	valid_0's l2: 7.36961e-10
# [392/424] target_391: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [141]	valid_0's rmse: 0.0102686	valid_0's l2: 0.000105444
# [393/424] target_392: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00735177	valid_0's l2: 5.40485e-05
# [394/424] target_393: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [54]	valid_0's rmse: 0.00262403	valid_0's l2: 6.88553e-06
# [395/424] target_394: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	valid_0's rmse: 0.0300818	valid_0's l2: 0.000904917
# [396/424] target_395: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	valid_0's rmse: 0.000103533	valid_0's l2: 1.07191e-08
# [397/424] target_396: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.000192476	valid_0's l2: 3.70471e-08
# [398/424] target_397: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	valid_0's rmse: 1.58928e-05	valid_0's l2: 2.52582e-10
# [399/424] target_398: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.0162367	valid_0's l2: 0.000263629
# [400/424] target_399: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0205675	valid_0's l2: 0.000423023
# [401/424] target_400: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [479]	valid_0's rmse: 0.00224866	valid_0's l2: 5.05648e-06
# [402/424] target_401: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [144]	valid_0's rmse: 0.00724282	valid_0's l2: 5.24584e-05
# [403/424] target_402: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00342887	valid_0's l2: 1.17572e-05
# [404/424] target_403: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [93]	valid_0's rmse: 1.96363e-05	valid_0's l2: 3.85586e-10
# [405/424] target_404: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	valid_0's rmse: 0.000398277	valid_0's l2: 1.58625e-07
# [406/424] target_405: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [77]	valid_0's rmse: 0.00254365	valid_0's l2: 6.47016e-06
# [407/424] target_406: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	valid_0's rmse: 0.0137921	valid_0's l2: 0.000190223
# [408/424] target_407: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00628916	valid_0's l2: 3.95535e-05
# [409/424] target_408: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	valid_0's rmse: 0.00387081	valid_0's l2: 1.49831e-05
# [410/424] target_409: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	valid_0's rmse: 0.0197966	valid_0's l2: 0.000391906
# [411/424] target_410: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	valid_0's rmse: 0.00352893	valid_0's l2: 1.24533e-05
# [412/424] target_411: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00120322	valid_0's l2: 1.44774e-06
# [413/424] target_412: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	valid_0's rmse: 0.0262791	valid_0's l2: 0.00069059
# [414/424] target_413: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [55]	valid_0's rmse: 7.42164e-05	valid_0's l2: 5.50808e-09
# [415/424] target_414: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.00982386	valid_0's l2: 9.65083e-05
# [416/424] target_415: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [89]	valid_0's rmse: 0.0109221	valid_0's l2: 0.000119293
# [417/424] target_416: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [93]	valid_0's rmse: 0.0063714	valid_0's l2: 4.05947e-05
# [418/424] target_417: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	valid_0's rmse: 1.82975e-05	valid_0's l2: 3.34797e-10
# [419/424] target_418: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [196]	valid_0's rmse: 0.00418937	valid_0's l2: 1.75508e-05
# [420/424] target_419: train_rows=1815, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [43]	valid_0's rmse: 1.15359e-05	valid_0's l2: 1.33078e-10
# [421/424] target_420: train_rows=1579, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.023108	valid_0's l2: 0.000533977
# [422/424] target_421: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	valid_0's rmse: 0.00752581	valid_0's l2: 5.66378e-05
# [423/424] target_422: train_rows=1699, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	valid_0's rmse: 0.00951564	valid_0's l2: 9.05474e-05
# [424/424] target_423: train_rows=1728, features=558
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [7]	valid_0's rmse: 0.000436555	valid_0's l2: 1.9058e-07
# Training finished in 1491.9s (GPU)
# Saved models to: /kaggle/working/models
# Example files: ['meta.json', 'target_0.pkl', 'target_1.pkl', 'target_10.pkl', 'target_100.pkl', 'target_101.pkl', 'target_102.pkl', 'target_103.pkl']
